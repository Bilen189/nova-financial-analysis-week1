# %%
jupyter notebook
# Out:
#   Cell In[1], line 1
#     jupyter notebook
#             ^
# SyntaxError: invalid syntax

# %%
print("Kernel working")
# Out:
# Kernel working

# %%
stock_technical_analysis.ipynb
